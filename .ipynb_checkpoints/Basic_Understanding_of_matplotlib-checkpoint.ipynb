# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
print x
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5. ]

# %%
print y
# Out:
# [  0.     0.25   1.     2.25   4.     6.25   9.    12.25  16.    20.25  25.  ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x, y, label='expoential')

# Add a legend
plt.legend(loc=0)

# %%
fig = plt.figure() # it is kind of canvas

ax1 = fig.add_subplot(221) # a new axes is created at the first position (1) on a grid of 2 rows and 2 columns.
ax1.plot([1,2,3,4,5], [10,5,10,5,0], 'r-')

ax2 = fig.add_subplot(222) 
ax2.plot([1,2,3,4], [1,4,9,16], 'k-')


ax3 = fig.add_subplot(223)
ax3.plot([1,2,3,4], [1,10,100,1000], 'b-')

ax4 = fig.add_subplot(224) # 
ax4.plot([1,2,3,4], [0,0,1,1], 'g-')

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax1.plot([1,2,3,4], [1,10,100,1000], 'b-')
ax2 = fig.add_subplot(122)
ax2.plot([1,2,3,4], [1,10,100,1000], 'b-')
plt.tight_layout()
